# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install -U pyobjc
# !pip install pillow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 5.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
from ocrmac import ocrmac

# %%
annotations = ocrmac.OCR('test.png',recognition_level='accurate').recognize(px=True)

print(annotations)
# Out:
# text GitHub: Let's build from here - bbox [(0.16817360120554542, 0.9324009325563325), (0.32730560843881845, 0.9324009325563325), (0.32730560843881845, 0.9184149185703185), (0.16817360120554542, 0.9184149185703185)] angles [0.0, -90.0, 180.0, 90.0]
# specific_angle 0.0 lower_bound -20 upper_bound 20
# specific_angle -90.0 lower_bound -108.0 upper_bound -72.0
# specific_angle 180.0 lower_bound 144.0 upper_bound 216.0
# specific_angle 90.0 lower_bound 72.0 upper_bound 108.0
# text github.com bbox [(0.17896907720955, 0.8923833528450333), (0.2476825016438325, 0.8931637996689714), (0.24779403152699817, 0.8768474169118157), (0.17908060709271567, 0.8760669700878775)] angles [0.6507372729691694, -89.60836343637034, -179.34926272703075, 90.39163656362966]
# specific_angle 0.0 lower_bound -20 upper_bound 20
# specific_angle -90.0 lower_bound -108.0 upper_bound -72.0
# specific_angle 180.0 lower_bound 144.0 upper_bound 216.0
# ...

# %%
img = ocrmac.OCR('test2.png',language_preference=['en-US'],recognition_level='accurate').annotate_PIL()

img
# Out:
# text Discounts on your wishlist bbox [(0.13144330885323566, 0.9840116275171444), (0.8762886508301223, 0.9840116275171444), (0.8762886508301223, 0.9374999997253806), (0.13144330885323566, 0.9374999997253806)] angles [0.0, -90.0, 180.0, 90.0]
# specific_angle 0.0 lower_bound -20 upper_bound 20
# specific_angle -90.0 lower_bound -108.0 upper_bound -72.0
# specific_angle 180.0 lower_bound 144.0 upper_bound 216.0
# specific_angle 90.0 lower_bound 72.0 upper_bound 108.0
# text Men's Polo Shirt bbox [(0.24484536987904396, 0.9389610379620599), (0.7680412255075542, 0.9389610379620599), (0.7680412255075542, 0.8967532457542677), (0.24484536987904396, 0.8967532457542677)] angles [0.0, -90.0, 180.0, 90.0]
# specific_angle 0.0 lower_bound -20 upper_bound 20
# specific_angle -90.0 lower_bound -108.0 upper_bound -72.0
# specific_angle 180.0 lower_bound 144.0 upper_bound 216.0
# specific_angle 90.0 lower_bound 72.0 upper_bound 108.0
# ...

# %%
img = ocrmac.OCR('test.png',language_preference=['en-US']).annotate_PIL()

img
# Out:
# <PIL.Image.Image image mode=RGBA size=1105x858>

# %%
# %%timeit
annotations =ocrmac.OCR('test.png',recognition_level='fast').recognize()
# Out:
# 214 ms ± 1.29 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
annotations =ocrmac.OCR('test.png', recognition_level='fast').recognize()
# Out:
# 211 ms ± 2.14 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
